# %%
import re
import pandas as pd
import numpy as np
import altair as alt
from vega_datasets import data
from pathlib import Path
from datetime import date
from ETLForElectionAndVaccinationData import *

# uses intermediate json files to speed things up
alt.data_transformers.enable('json')

## Color global variables
TO_OTHER =   "#556B2F" 
TO_DEMOCRAT =  "#11A3D6"
TO_REPUBLICAN = "#8C1616"
STAYED_DEMOCRAT  =  '#0015BC'
STAYED_REPUBLICAN = '#FF0000'
STAYED_OTHER = '#B4D3B2'

segment_color_dict = {
    'TO_OTHER' : TO_OTHER ,
    'TO_DEMOCRAT'  : TO_DEMOCRAT,
    'TO_REPUBLICAN' : TO_REPUBLICAN,
    'STAYED_DEMOCRAT'  :  STAYED_DEMOCRAT,
    'STAYED_REPUBLICAN' : STAYED_REPUBLICAN,
    'STAYED_OTHER' : STAYED_OTHER
}

color_segment_dict = {TO_OTHER:"To other",
                      TO_DEMOCRAT:"To Democrat", 
                      TO_REPUBLICAN:"To Republican", 
                      STAYED_DEMOCRAT:"Stayed Democrat",
                      STAYED_REPUBLICAN:"Stayed Republican",
                      STAYED_OTHER:"Stayed Other"}

DataFolder = Path("../DataForPresidentialElectionsAndCovid/")

# %%
def getUnemploymentRate():
    """
        THIS FUNCTION reads the county level unemployment rate from the 2020 dataset published by the BLS
        and 
        
        Functions called: None
        
        Input: None
        Returns: Dataframe election_winners_df with the following set of columns.
                 Note: Granularity = COUNTYFP.
        
            state                  (full name)
            state_po               (2-letter abbreviation)
            CTYNAME                (full name)
            COUNTYFP               (FIPS number) Questions
            party_winner_2020
            totalvotes_2020
            fractionalvotes_2020
            party_winner_2016
            totalvotes_2016
            fractionalvotes_2016
                
    """
    unemployment_df = pd.read_excel(DataFolder / r"laucntycur14.xlsx",
                                    names=["LAUS_code","state_FIPS","county_FIPS","county_name_and_state_abbreviation","Period","labor_force","employed","unemployed","unemployment_rate"],
                                    header=5,
                                    skipfooter=3)
    
    # Format the county FIPS as the state FIPS followed by the county FIPS
    concatenate_fips = lambda x : int(str(x["state_FIPS"]) + "{:03d}".format(x["county_FIPS"]))
    unemployment_df["COUNTYFP"] = unemployment_df.apply(concatenate_fips, axis=1)
    # Keep only US mainland states
    unemployment_df = unemployment_df[unemployment_df["COUNTYFP"] < 57000]
    # extract state and county names
    extract_names_regex = r"^(?P<CTYNAME>.*),\s(?P<state>[A-Z]{2})$"
    extract_county_names = lambda x : re.search(extract_names_regex,x).group("CTYNAME") if x != "District of Columbia" else "District of Columbia"
    extract_state_names = lambda x : re.search(extract_names_regex,x).group("state") if x != "District of Columbia" else "District of Columbia"
    unemployment_df["CTYNAME"] = unemployment_df["county_name_and_state_abbreviation"].apply(extract_county_names)
    unemployment_df["state"] = unemployment_df["county_name_and_state_abbreviation"].apply(extract_state_names)
    # Reformat present month which ends with " p"
    reformat_present_month = lambda x: x[:-2] if x[-2:] ==" p" else x 
    unemployment_df["Period"] = unemployment_df["Period"].apply(reformat_present_month)
    # Convert period to datetime
    unemployment_df["month"] = pd.to_datetime(unemployment_df["Period"], format="%b-%y")
    unemployment_df.drop(columns=["state_FIPS", "county_FIPS", "LAUS_code","county_name_and_state_abbreviation","Period","labor_force","employed","unemployed"], inplace=True)
    
    covid_df = getCasesRollingAveragePer100K()
    # Remove non mainland US states
    covid_df = covid_df[covid_df["COUNTYFP"] < 57000]
    # Change period to month and average cases per 100K per month and county
    covid_df["year_month"] = covid_df["date"].dt.to_period('M')
    covid_df.drop(columns=["date"], inplace=True)
    covid_df = covid_df.groupby(["year_month", "COUNTYFP"]).sum()
    covid_df.reset_index(inplace=True)
    # Get back the month period as a timestamp
    covid_df["month"] = covid_df["year_month"].apply(lambda x: x.to_timestamp(freq="D", how="start"))
    covid_df.drop(columns=["year_month"], inplace=True)
    
    uncemployment_covid_df = pd.merge(unemployment_df, covid_df, how="left", on=["month", "COUNTYFP"])
    
    election_df = getElectionData()
    election_df = election_df[["COUNTYFP", "party_winner_2020"]]
    
    
    uncemployment_covid_df = pd.merge(uncemployment_covid_df, election_df, how="left", on="COUNTYFP" )
    # uncemployment_covid_df.join(covid_df, on="COUNTYFP", how="left")
    
    return uncemployment_covid_df

# %%
unemployment_covid_df = getUnemploymentRate()
unemployment_covid_df.dropna(inplace=True)
unemployment_covid_df
# Out:
#       unemployment_rate  COUNTYFP            CTYNAME state      month  \
# 0                  10.9      1001     Autauga County    AL 2020-04-01
# 1                  14.5      1003     Baldwin County    AL 2020-04-01
# 2                   9.3      1005     Barbour County    AL 2020-04-01
# 3                  17.1      1007        Bibb County    AL 2020-04-01
# 4                   9.1      1009      Blount County    AL 2020-04-01
# ...                 ...       ...                ...   ...        ...
# 43969               6.7     56037  Sweetwater County    WY 2021-05-01
# 43970               5.9     56039       Teton County    WY 2021-05-01
# 43971               6.1     56041       Uinta County    WY 2021-05-01
# 43972               4.7     56043    Washakie County    WY 2021-05-01
# 43973                 4     56045      Weston County    WY 2021-05-01
#
#        cases_avg_per_100k  deaths_avg_per_100k party_winner_2020
# 0                   64.41                 7.56        REPUBLICAN
# 1                   68.61                 1.35        REPUBLICAN
# 2                  142.38                 1.16        REPUBLICAN
# 3                  200.16                 0.00        REPUBLICAN
# 4                   51.42                 0.00        REPUBLICAN
# ...                   ...                  ...               ...
# 43969              686.55                 4.76        REPUBLICAN
# 43970              277.79                 0.00          DEMOCRAT
# 43971              498.66                 4.97        REPUBLICAN
# 43972              318.38                 0.00        REPUBLICAN
# 43973               68.00                 0.00        REPUBLICAN
#
# [43974 rows x 8 columns]

# %%
unemployment_covid_df.isnull().sum()/len(unemployment_covid_df) * 100
# Out:
# unemployment_rate      0.000000
# COUNTYFP               0.000000
# CTYNAME                0.000000
# state                  0.000000
# month                  0.000000
# cases_avg_per_100k     1.701005
# deaths_avg_per_100k    1.701005
# party_winner_2020      0.891436
# dtype: float64

# %%
unemployment_covid_df[unemployment_covid_df["party_winner_2020"].isnull()].reset_index()
# Out:
#      index unemployment_rate  COUNTYFP                       CTYNAME state  \
# 0       70              12.1      2050            Bethel Census Area    AK
# 1       71              13.3      2060           Bristol Bay Borough    AK
# 2       72              25.5      2068                Denali Borough    AK
# 3       73               9.8      2070        Dillingham Census Area    AK
# 4       74                10      2090  Fairbanks North Star Borough    AK
# ..     ...               ...       ...                           ...   ...
# 387  40926               6.5      2275         Wrangell Borough/city    AK
# 388  40927               7.7      2282          Yakutat Borough/city    AK
# 389  40928              12.3      2290     Yukon-Koyukuk Census Area    AK
# 390  41057               8.3      6077            San Joaquin County    CA
# 391  43244               7.7     46102          Oglala Lakota County    SD
#
#          month  cases_avg_per_100k  deaths_avg_per_100k party_winner_2020
# 0   2020-04-01                5.46                 0.00               NaN
# 1   2020-04-01                 NaN                  NaN               NaN
# 2   2020-04-01                 NaN                  NaN               NaN
# 3   2020-04-01                 NaN                  NaN               NaN
# 4   2020-04-01               58.89                 2.10               NaN
# ..         ...                 ...                  ...               ...
# 387 2021-05-01              142.75                 0.00               NaN
# 388 2021-05-01                 NaN                  NaN               NaN
# 389 2021-05-01              152.88                 0.00               NaN
# 390 2021-05-01              206.45                 9.81               NaN
# 391 2021-05-01               78.58                 0.00               NaN
#
# [392 rows x 9 columns]

# %%
unemployment_covid_df[(unemployment_covid_df["party_winner_2020"].isnull()) & (unemployment_covid_df["state"] == "AK") & (unemployment_covid_df["month"] == unemployment_covid_df["month"][0])].reset_index()
# Out:
#     index unemployment_rate  COUNTYFP                            CTYNAME  \
# 0   40903              12.8      2050                 Bethel Census Area
# 1   40904               5.9      2060                Bristol Bay Borough
# 2   40905              12.3      2068                     Denali Borough
# 3   40906               8.9      2070             Dillingham Census Area
# 4   40907               5.1      2090       Fairbanks North Star Borough
# 5   40908              10.8      2100                     Haines Borough
# 6   40909              10.7      2105          Hoonah-Angoon Census Area
# 7   40910               5.1      2110                Juneau Borough/city
# 8   40911               7.7      2122            Kenai Peninsula Borough
# 9   40912               7.7      2130          Ketchikan Gateway Borough
# 10  40913               6.4      2150              Kodiak Island Borough
# 11  40914              21.2      2158               Kusilvak Census Area
# 12  40915                10      2164         Lake and Peninsula Borough
# 13  40916                 7      2170          Matanuska-Susitna Borough
# 14  40917              11.8      2180                   Nome Census Area
# 15  40918               6.3      2185                North Slope Borough
# 16  40919              12.9      2188           Northwest Arctic Borough
# 17  40920               6.9      2195                 Petersburg Borough
# 18  40921               7.5      2198  Prince of Wales-Hyder Census Area
# 19  40922               4.9      2220                 Sitka Borough/city
# 20  40923                13      2230               Skagway Municipality
# 21  40924               6.5      2240    Southeast Fairbanks Census Area
# 22  40925               7.8      2261         Valdez-Cordova Census Area
# 23  40926               6.5      2275              Wrangell Borough/city
# 24  40927               7.7      2282               Yakutat Borough/city
# 25  40928              12.3      2290          Yukon-Koyukuk Census Area
#
#    state      month  cases_avg_per_100k  deaths_avg_per_100k party_winner_2020
# 0     AK 2021-05-01              165.33                 7.02               NaN
# 1     AK 2021-05-01                 NaN                  NaN               NaN
# 2     AK 2021-05-01              463.23                 0.00               NaN
# 3     AK 2021-05-01               26.19                 0.00               NaN
# 4     AK 2021-05-01              580.02                 6.53               NaN
# 5     AK 2021-05-01               45.18                 0.00               NaN
# 6     AK 2021-05-01                 NaN                  NaN               NaN
# 7     AK 2021-05-01              217.50                 0.00               NaN
# 8     AK 2021-05-01              222.67                 0.00               NaN
# 9     AK 2021-05-01             1563.08                 0.00               NaN
# 10    AK 2021-05-01              148.46                 7.70               NaN
# 11    AK 2021-05-01              485.97                 0.00               NaN
# 12    AK 2021-05-01                 NaN                  NaN               NaN
# 13    AK 2021-05-01              423.76                11.07               NaN
# 14    AK 2021-05-01              172.77                 0.00               NaN
# 15    AK 2021-05-01              217.48                 0.00               NaN
# 16    AK 2021-05-01              119.90                 0.00               NaN
# 17    AK 2021-05-01              179.26                 0.00               NaN
# 18    AK 2021-05-01              803.75                 0.00               NaN
# 19    AK 2021-05-01              215.30                 0.00               NaN
# 20    AK 2021-05-01               24.16                 0.00               NaN
# 21    AK 2021-05-01              924.62                14.49               NaN
# 22    AK 2021-05-01              478.36                 0.00               NaN
# 23    AK 2021-05-01              142.75                 0.00               NaN
# 24    AK 2021-05-01                 NaN                  NaN               NaN
# 25    AK 2021-05-01              152.88                 0.00               NaN

# %%
election_df = getElectionData()
election_df[election_df["COUNTYFP"]==51800]
# Out:
#          state state_po       CTYNAME  COUNTYFP party_winner_2020  \
# 2950  VIRGINIA       VA  SUFFOLK CITY     51800          DEMOCRAT
#
#       totalvotes_2020  fractionalvotes_2020 party_winner_2016  \
# 2950          49642.0              0.577656          DEMOCRAT
#
#       totalvotes_2016  fractionalvotes_2016
# 2950          43240.0               0.53839

# %%
election_df
# Out:
#         state state_po     CTYNAME  COUNTYFP party_winner_2020  \
# 0     ALABAMA       AL     AUTAUGA      1001        REPUBLICAN
# 1     ALABAMA       AL     BALDWIN      1003        REPUBLICAN
# 2     ALABAMA       AL     BARBOUR      1005        REPUBLICAN
# 3     ALABAMA       AL        BIBB      1007        REPUBLICAN
# 4     ALABAMA       AL      BLOUNT      1009        REPUBLICAN
# ...       ...      ...         ...       ...               ...
# 3148  WYOMING       WY  SWEETWATER     56037        REPUBLICAN
# 3149  WYOMING       WY       TETON     56039          DEMOCRAT
# 3150  WYOMING       WY       UINTA     56041        REPUBLICAN
# 3151  WYOMING       WY    WASHAKIE     56043        REPUBLICAN
# 3152  WYOMING       WY      WESTON     56045        REPUBLICAN
#
#       totalvotes_2020  fractionalvotes_2020 party_winner_2016  \
# 0             27770.0              0.714368        REPUBLICAN
# 1            109679.0              0.761714        REPUBLICAN
# 2             10518.0              0.534512        REPUBLICAN
# 3              9595.0              0.784263        REPUBLICAN
# 4             27588.0              0.895716        REPUBLICAN
# ...               ...                   ...               ...
# 3148          16698.0              0.732363        REPUBLICAN
# 3149          14787.0              0.665990          DEMOCRAT
# 3150           9459.0              0.792473        REPUBLICAN
# 3151           4032.0              0.804812        REPUBLICAN
# 3152           3560.0              0.872753        REPUBLICAN
#
#       totalvotes_2016  fractionalvotes_2016
# 0             24973.0              0.727666
# 1             95215.0              0.765457
# 2             10469.0              0.520967
# 3              8819.0              0.764032
# 4             25588.0              0.893348
# ...               ...                   ...
# 3148          17130.0              0.709515
# 3149          12627.0              0.579235
# 3150           8470.0              0.726564
# 3151           3814.0              0.763241
# 3152           3526.0              0.860182
#
# [3153 rows x 10 columns]

# %%
election_df[election_df["state_po"]=="AK"]
# Out:
#       state state_po      CTYNAME  COUNTYFP party_winner_2020  \
# 67   ALASKA       AK   DISTRICT 1      2001        REPUBLICAN
# 68   ALASKA       AK  DISTRICT 10      2010        REPUBLICAN
# 69   ALASKA       AK  DISTRICT 11      2011        REPUBLICAN
# 70   ALASKA       AK  DISTRICT 12      2012        REPUBLICAN
# 71   ALASKA       AK  DISTRICT 13      2013        REPUBLICAN
# 72   ALASKA       AK  DISTRICT 14      2014        REPUBLICAN
# 73   ALASKA       AK  DISTRICT 15      2015        REPUBLICAN
# 74   ALASKA       AK  DISTRICT 16      2016          DEMOCRAT
# 75   ALASKA       AK  DISTRICT 17      2017          DEMOCRAT
# 76   ALASKA       AK  DISTRICT 18      2018          DEMOCRAT
# 77   ALASKA       AK  DISTRICT 19      2019          DEMOCRAT
# 78   ALASKA       AK   DISTRICT 2      2002        REPUBLICAN
# 79   ALASKA       AK  DISTRICT 20      2020          DEMOCRAT
# 80   ALASKA       AK  DISTRICT 21      2021          DEMOCRAT
# 81   ALASKA       AK  DISTRICT 22      2022        REPUBLICAN
# 82   ALASKA       AK  DISTRICT 23      2023          DEMOCRAT
# 83   ALASKA       AK  DISTRICT 24      2024        REPUBLICAN
# 84   ALASKA       AK  DISTRICT 25      2025          DEMOCRAT
# 85   ALASKA       AK  DISTRICT 26      2026        REPUBLICAN
# 86   ALASKA       AK  DISTRICT 27      2027          DEMOCRAT
# 87   ALASKA       AK  DISTRICT 28      2028          DEMOCRAT
# 88   ALASKA       AK  DISTRICT 29      2029        REPUBLICAN
# 89   ALASKA       AK   DISTRICT 3      2003        REPUBLICAN
# 90   ALASKA       AK  DISTRICT 30      2030        REPUBLICAN
# 91   ALASKA       AK  DISTRICT 31      2031        REPUBLICAN
# 92   ALASKA       AK  DISTRICT 32      2032        REPUBLICAN
# 93   ALASKA       AK  DISTRICT 33      2033          DEMOCRAT
# 94   ALASKA       AK  DISTRICT 34      2034          DEMOCRAT
# 95   ALASKA       AK  DISTRICT 35      2035          DEMOCRAT
# 96   ALASKA       AK  DISTRICT 36      2036        REPUBLICAN
# 97   ALASKA       AK  DISTRICT 37      2037          DEMOCRAT
# 98   ALASKA       AK  DISTRICT 38      2038          DEMOCRAT
# 99   ALASKA       AK  DISTRICT 39      2039          DEMOCRAT
# 100  ALASKA       AK   DISTRICT 4      2004          DEMOCRAT
# 101  ALASKA       AK  DISTRICT 40      2040          DEMOCRAT
# 102  ALASKA       AK   DISTRICT 5      2005          DEMOCRAT
# 103  ALASKA       AK   DISTRICT 6      2006        REPUBLICAN
# 104  ALASKA       AK   DISTRICT 7      2007        REPUBLICAN
# 105  ALASKA       AK   DISTRICT 8      2008        REPUBLICAN
# 106  ALASKA       AK   DISTRICT 9      2009        REPUBLICAN
# 107  ALASKA       AK  DISTRICT 99      2099          DEMOCRAT
#
#      totalvotes_2020  fractionalvotes_2020 party_winner_2016  totalvotes_2016  \
# 67            7314.0              0.480038        REPUBLICAN           6638.0
# 68           11205.0              0.721196        REPUBLICAN           9040.0
# 69           10628.0              0.667670        REPUBLICAN           9689.0
# 70           11238.0              0.702349        REPUBLICAN           9543.0
# 71            7713.0              0.603138        REPUBLICAN           6533.0
# 72           11443.0              0.586734        REPUBLICAN          10420.0
# 73            5559.0              0.480482        REPUBLICAN           4982.0
# 74            8118.0              0.526484          DEMOCRAT           7436.0
# 75            7239.0              0.571350          DEMOCRAT           6788.0
# 76            7720.0              0.606347          DEMOCRAT           7402.0
# 77            5301.0              0.588191          DEMOCRAT           4792.0
# 78            6136.0              0.598761        REPUBLICAN           5492.0
# 79            7497.0              0.651060          DEMOCRAT           7140.0
# 80            9429.0              0.574186          DEMOCRAT           8647.0
# 81            9520.0              0.492017        REPUBLICAN           8372.0
# 82            7739.0              0.492312        REPUBLICAN           6924.0
# 83           10428.0              0.515727        REPUBLICAN           9080.0
# 84            9325.0              0.493298        REPUBLICAN           8127.0
# 85           10111.0              0.518544        REPUBLICAN           8905.0
# 86            9506.0              0.509573        REPUBLICAN           8783.0
# 87           12749.0              0.491333        REPUBLICAN          11427.0
# 88           10747.0              0.694519        REPUBLICAN           9394.0
# 89            8385.0              0.724627        REPUBLICAN           7613.0
# 90           10176.0              0.705582        REPUBLICAN           8950.0
# 91           12410.0              0.561724        REPUBLICAN          10182.0
# 92            8335.0              0.532693        REPUBLICAN           7472.0
# 93           10955.0              0.687814          DEMOCRAT           9934.0
# 94           10729.0              0.537142          DEMOCRAT           9431.0
# 95           10102.0              0.496040        REPUBLICAN           9042.0
# 96            9292.0              0.550366        REPUBLICAN           8264.0
# 97            5142.0              0.497861          DEMOCRAT           5062.0
# 98            5299.0              0.604265          DEMOCRAT           5095.0
# 99            5891.0              0.607707          DEMOCRAT           5639.0
# 100          10511.0              0.508515          DEMOCRAT           9521.0
# 101           4603.0              0.503585          DEMOCRAT           4610.0
# 102           8654.0              0.485787        REPUBLICAN           7906.0
# 103           9460.0              0.609937        REPUBLICAN           8460.0
# 104           9622.0              0.730306        REPUBLICAN           8294.0
# 105           9912.0              0.768563        REPUBLICAN           8073.0
# 106          10993.0              0.708360        REPUBLICAN           8954.0
# 107            433.0              0.861432               NaN              NaN
#
#      fractionalvotes_2016
# 67               0.479060
# 68               0.691925
# 69               0.665084
# 70               0.694645
# 71               0.616562
# 72               0.573704
# 73               0.506825
# 74               0.442980
# 75               0.484679
# 76               0.528101
# 77               0.556970
# 78               0.580481
# 79               0.581373
# 80               0.488493
# 81               0.502031
# 82               0.468804
# 83               0.518612
# 84               0.469546
# 85               0.510724
# 86               0.465103
# 87               0.474578
# 88               0.675644
# 89               0.709707
# 90               0.692067
# 91               0.551660
# 92               0.503747
# 93               0.601772
# 94               0.447461
# 95               0.453992
# 96               0.539690
# 97               0.478269
# 98               0.541315
# 99               0.557191
# 100              0.437139
# 101              0.507158
# 102              0.465849
# 103              0.582624
# 104              0.715578
# 105              0.758826
# 106              0.681260
# 107                   NaN
